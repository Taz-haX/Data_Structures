# %% [markdown]
# <a href="https://colab.research.google.com/github/Taz-haX/Data_Structures/blob/main/Doubly_Linked_List_Coding_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instructions:
# DLL: Swap First and Last
# Swap the values of the first and last node

# Method name:
# swap_first_last

# Note that the pointers to the nodes themselves are not swapped - only their values are exchanged.

class Node:
    def __init__(self, value=0):
        self.value = value
        self.prev = None
        self.next = None

class DL_list:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def insert(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
            self.length +=1
        else:
            new_node.prev = self.tail
            self.tail.next = new_node
            self.tail = new_node
            self.length += 1

    def swap_first_last(self):
        if self.length <= 1:
            print('Function not Possible')
        else:
            self.head.value, self.tail.value = self.tail.value, self.head.value

    def show_list(self):
        temp = self.head
        while temp!=None:
            if temp.next != None:
                print(f'{temp.value}-->',end='')
            else:
                print(f'{temp.value}')
            temp = temp.next

d1 = DL_list()
d1.show_list()
d1.insert(78)
d1.insert(90)
d1.insert(23)
d1.show_list()
print(d1.head.value, d1.tail.value)
d1.swap_first_last()
print('================')
print(d1.head.value, d1.tail.value)
# Out:
# 78-->90-->23
# 78 23
# ================
# 23 78

# %%
# Instructions:
# DLL: Reverse
# Create a new method called reverse that reverses the order of the nodes in the list, i.e., the first node becomes the last node, the second node becomes the second-to-last node, and so on.

class Node:
    def __init__(self, value=0):
        self.value = value
        self.prev = None
        self.next = None

class DL_list:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def insert(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
            self.length +=1
        else:
            new_node.prev = self.tail
            self.tail.next = new_node
            self.tail = new_node
            self.length += 1

    def reverse(self):
        if self.length <= 1:
            print(f'Not Possible')
        else:

            self.head, self.tail = self.tail, self.head
            temp = self.head
            while temp!=None:
                temp.next = temp.prev
                temp.prev = None
                temp = temp.next

    def show_list(self):
        temp = self.head
        while temp!=None:
            if temp.next != None:
                print(f'{temp.value}-->',end='')
            else:
                print(f'{temp.value}')
            temp = temp.next

d1 = DL_list()
d1.show_list()
d1.insert(78)
d1.insert(90)
d1.insert(23)
d1.insert(26)
d1.insert(67)
d1.show_list()
d1.reverse()
d1.show_list()
# Out:
# 78-->90-->23-->26-->67
# 67-->26-->23-->90-->78

# %%
# Instructions:
# DLL: Palindrome Checker
# Write a method to determine whether a given doubly linked list reads the same forwards and backwards.

# For example, if the list contains the values [1, 2, 3, 2, 1], then the method should return True, since the list is a palindrome.

# If the list contains the values [1, 2, 3, 4, 5], then the method should return False, since the list is not a palindrome.

class Node:
    def __init__(self, value=0):
        self.value = value
        self.prev = None
        self.next = None

class DL_list:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def insert(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
            self.length +=1
        else:
            new_node.prev = self.tail
            self.tail.next = new_node
            self.tail = new_node
            self.length += 1

    def is_palindrome(self):
        tok = 0
        bok = 0
        if self.length%2==0:
            print(f'Not Palindrome')
        else:
            tot = self.length//2
            temp = self.head
            prep = self.tail
            for i in range(tot):
                tok = temp.value
                bok = prep.value
                if tok==bok:
                    pass
                else:
                    return f'Not a Palindrome'
                temp = temp.next
                prep = prep.prev
            return f'Is a Palindrome'

    def show_list(self):
        temp = self.head
        while temp!=None:
            if temp.next != None:
                print(f'{temp.value}-->',end='')
            else:
                print(f'{temp.value}')
            temp = temp.next

d1 = DL_list()
d1.show_list()
d1.insert(78)
d1.insert(90)
d1.insert(23)
d1.insert(26)
d1.insert(67)
d1.show_list()
print(d1.is_palindrome())
d2 = DL_list()
d2.insert(1)
d2.insert(2)
d2.insert(3)
d2.insert(2)
d2.insert(1)
d2.show_list()
print(d2.is_palindrome())
# Out:
# 78-->90-->23-->26-->67
# Not a Palindrome
# 1-->2-->3-->2-->1
# Is a Palindrome

# %%
# Instructions:
# DLL: Swap Nodes in Pairs
# You are given a doubly linked list.

# Implement a method called swap_pairs within the class that swaps the values of adjacent nodes in the linked list. The method should not take any input parameters.

class Node:
    def __init__(self, value=0):
        self.value = value
        self.prev = None
        self.next = None

class DL_list:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def insert(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
            self.length +=1
        else:
            new_node.prev = self.tail
            self.tail.next = new_node
            self.tail = new_node
            self.length += 1

    def swap_pairs(self):
        if self.length<=1:
            pass
        else:
            temp = self.head
            prep = temp.next
            if self.length % 2 == 0:
                while temp != None:
                    temp.value, prep.value = prep.value, temp.value
                    temp = prep.next
                    prep = temp.next
            else:
                while temp != self.tail:
                    temp.value, prep.value = prep.value, temp.value
                    temp = prep.next
                    prep = temp.next

    def show_list(self):
        temp = self.head
        while temp!=None:
            if temp.next != None:
                print(f'{temp.value}-->',end='')
            else:
                print(f'{temp.value}')
            temp = temp.next

d1 = DL_list()
d1.show_list()
d1.insert(78)
d1.insert(90)
d1.insert(23)
d1.insert(26)
d1.insert(67)
d1.show_list()
d1.swap_pairs()
d1.show_list()
# Out:
# 78-->90-->23-->26-->67
# 90-->78-->26-->23-->67
